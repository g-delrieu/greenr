# %%
import pandas as pd
data = pd.read_csv('Final_conversion_table.csv')

# %%
data = data.drop(['Average tablespoon (grams)', 'Source', 'Average Unit (if applicable) (grams)', 'Source.1'], axis = 1)
data.columns = ['name','tablespoon','unit','ghg']
data = data.set_index('name')

# %%
data
# Out:
#                          tablespoon   unit   ghg
# name
# Wheat & Rye (Bread)         0.00981    NaN   1.3
# Maize (Meal)                0.00800    NaN   1.2
# Barley (Beer)               0.00938    NaN   1.2
# Oatmeal                     0.00563    NaN   2.6
# Rice                        0.01400    NaN   3.7
# Potatoes                    0.00872  0.213   0.5
# Cassava                     0.00763    NaN   1.1
# Cane Sugar                  0.01250    NaN   3.2
# Beet Sugar                  0.01250    NaN   1.8
# Other Pulses                0.01268    NaN   1.4
# Peas                        0.00812    NaN   0.8
# Nuts                        0.00937    NaN  -1.3
# Groundnuts                  0.00913    NaN   3.3
# Soymilk                     0.01519    NaN   0.9
# Tofu                        0.01575    NaN   2.6
# Soybean Oil                 0.01400    NaN   3.9
# Palm Oil                    0.01350    NaN   7.2
# Sunflower Oil               0.01400    NaN   3.5
# Rapeseed Oil                0.01363    NaN   3.5
# Olive Oil                   0.01400    NaN   5.1
# Tomatoes                    0.01400  0.123   0.7
# Onions & Leeks              0.00325  0.110   0.4
# Root Vegetables                 NaN  0.073   0.4
# Brassicas                       NaN  0.908   0.4
# Other Vegetables                NaN  0.256   0.4
# Citrus Fruit                    NaN  0.120   0.3
# Bananas                         NaN  0.118   0.8
# Apples                          NaN  0.080   0.4
# Berries & Grapes                NaN  0.007   1.4
# Wine                        0.01475    NaN   1.6
# Other Fruit                 0.00000  0.278   0.7
# Coffee                      0.00700    NaN   8.2
# Dark Chocolate              0.01100    NaN   5.0
# Bovine Meat (beef herd)     0.02400  0.225  60.4
# Lamb & Mutton               0.01575  0.087  40.6
# Pig Meat                    0.02000  0.115  10.6
# Poultry Meat                0.01200  1.356   7.5
# Milk                        0.01513    NaN   2.7
# Cheese                      0.01410    NaN  18.6
# Eggs                            NaN  0.050   4.2
# Fish (farmed)               0.01200  0.250   7.9
# Crustaceans (farmed)        0.01200  0.050  14.7

# %%
name = ['Oatmeal', 'Rice', 'Potatoes', 'Eggs']
qty = [1, 0.5, 3, 2]
unit = ['tablespoon', 'tablespoon', 'unit', 'grams']

test_df = pd.DataFrame(list(zip(name, qty, unit)), columns = ['name', 'qty', 'unit'])

# %%
test_df.unit[2]
# Out:
# 'unit'

# %%
import pandas as pd
data = pd.read_csv('Final_conversion_table.csv')

data = data.drop(['Average tablespoon (grams)', 'Source', 'Average Unit (if applicable) (grams)', 'Source.1'], axis = 1)
data.columns = ['name','tablespoon','unit','ghg']
data = data.set_index('name')

def ghg_calc(df):
    impact = []
    for i in range(len(df.unit)): 
        if df.unit[i] == 'tablespoon':
            impact.append(df.qty[i]*data.tablespoon[df.name[i]]*data.ghg[df.name[i]])
        elif df.unit[i] == 'unit':
            impact.append(df.qty[i]*data.unit[df.name[i]]*data.ghg[df.name[i]])
        elif df.unit[i] == 'gram':
            impact.append((df.qty[i]/1000)*data.unit[df.name[i]]*data.ghg[df.name[i]])
        elif df.unit[i] == 'milliliter':
            impact.append((df.qty[i]/1000)*data.unit[df.name[i]]*data.ghg[df.name[i]])
        elif df.unit[i] == 'kilogram':
            impact.append(df.qty[i]*data.ghg[df.name[i]])
        elif df.unit[i] == 'liter':
            impact.append(df.qty[i]*data.ghg[df.name[i]])
        else:
            impact.append(0)

    return sum(impact)

#pd.DataFrame(list(zip(df.name, impact)))

# %%
ghg_calc(test_df)
# Out:
# 0.360038
