# %%
from googletrans import Translator

# %%
import re
import json
import pandas as pd
import requests
from bs4 import BeautifulSoup

def marmiton_to_df(url):
    page = requests.get(f'{url}')
    soup = BeautifulSoup(page.content, 'html.parser')
    tmp = soup.find_all('script', type = "text/javascript")[9]
    ingredient = json.loads(re.search('(?<=recipesData \= )(.*?)(?=;)', str(tmp.contents[0])).group(0))['recipes'][0]['ingredients']

    #translating
    translator = Translator()

    ingredients = []
    qty = []
    unit = []
    for i in range(len(ingredient)):
        ingredients.append(translator.translate(ingredient[i]['name'], src ='fr').text)
        qty.append(ingredient[i]['qty'])
        #import pdb; pdb.set_trace()
        if ingredient[i]['unit']== '':
            unit.append('unit')
        elif translator.translate(ingredient[i]['unit'], src ='fr').text == 'g':
            unit.append('gram')
        elif translator.translate(ingredient[i]['unit'], src ='fr').text == 'spoon':
            unit.append('teaspoon')

        else:
            unit.append(translator.translate(ingredient[i]['unit'], src ='fr').text)
        #
    final_df = pd.DataFrame(list(zip(qty, unit, ingredients)), columns = ['qty', 'unit', 'ingredients'])
    final_df = final_df[final_df['ingredients'].notna()]
    final_df = final_df[final_df['unit'].notna()]
    final_df = final_df[final_df['unit'] != 'teaspoon']
    
    return final_df

# %%
# %%time

marmiton_to_df('https://www.marmiton.org/recettes/recette_gratin-de-courge-butternut_34853.aspx')
# Out:
# CPU times: user 243 ms, sys: 17 ms, total: 260 ms
# Wall time: 1.64 s
#    qty        unit      ingredients
# 0    1        unit           squash
# 1  200        gram     smoked bacon
# 2    2  tablespoon            herbs
# 3    2  tablespoon          pinions
# 4             unit           pepper
# 5             unit             salt
# 6             unit           nutmeg
# 7             unit     liquid cream
# 8             unit  Grated parmesan

# %%
def chefkoch_to_list(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    tmp = soup.find_all('script', type = "application/ld+json")[1]
    ing_list = json.loads(str(tmp).strip('<script type="application/ld+json">    '))['recipeIngredient']
    de_list = []
    for ing in ing_list: 
        de_list.append(Translator().translate(ing, src ='de').text)
    return de_list

# %%
# %%time 

chefkoch_to_list('https://www.chefkoch.de/rezepte/1616691268862802/Zucchini-Lasagne.html')
# Out:
# CPU times: user 957 ms, sys: 55.1 ms, total: 1.01 s
# Wall time: 4.4 s
# ['1 kg zucchini, large, thick',
#  '500 g ground beef',
#  '1 large onion (s)',
#  '1 clove of garlic',
#  '1 can of tomato (s), chunky',
#  '1 packet of cream cheese',
#  '100 ml of milk',
#  'n. B. sour cream',
#  '1 tbsp tomato paste',
#  '150 g cheese, grated',
#  'olive oil',
#  'oregano',
#  'thyme',
#  'parsley',
#  'salt and pepper',
#  'Sweet paprika']

# %%
from urllib.parse import urlparse
o = urlparse("https://www.chefkoch.de/rezepte/2258521361223393/Fisch-Gemuese-Pfanne-mit-Kokosmilch-Low-carb.html")
o
# Out:
# ParseResult(scheme='https', netloc='www.chefkoch.de', path='/rezepte/2258521361223393/Fisch-Gemuese-Pfanne-mit-Kokosmilch-Low-carb.html', params='', query='', fragment='')

# %%
from urllib.parse import urlparse


    o = urlparse(url)
    if o.netloc == 'www.marmiton.org':
        try:
            #go the marmiton way
        except:
            #throw error
    elif o.netlock == 'www.bbc.co.uk':
        try:
            #go the bbc way
        except:
            #throw error
    elif o.netlock == 'www.chefkoch.de':
        try:
            #go the chefkoch way
        except: 
            #throw error
    else:
        try:
            #text field
        except:
            #throw error
# Out:
# True

# %%
page = requests.get('https://www.marmiton.org/recettes/recette_gratin-de-courge-butternut_34853.aspx')
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="fr">
# <head>
# <script type="text/javascript">
# window.gdprAppliesGlobally=true;(function(){function a(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}
# else{setTimeout(function(){a(e)},5)}}}function e(n,r,o,c,s){function e(e,t,n,a){if(typeof n!=="function"){return}if(!window[r]){window[r]=[]}var i=false;if(s){i=s(e,t,n)}if(!i){window[r].push({command:e,parameter:t,callback:n,version:a})}}e.stub=true;function t(a){if(!window[n]||window[n].stub!==true){return}if(!a.data){return}
# var i=typeof a.data==="string";var e;try{e=i?JSON.parse(a.data):a.data}catch(t){return}if(e[o]){var r=e[o];window[n](r.command,r.parameter,function(e,t){var n={};n[c]={returnValue:e,success:t,callId:r.callId};a.source.postMessage(i?JSON.stringify(n):n,"*")},r.version)}}
# ...

# %%
soup.find_all("meta", attrs={'name':'classification'})
# Out:
# [<meta content="cuisine recettes gratuit" name="classification"/>]

# %%
page = requests.get('https://www.bbc.co.uk/food/recipes/salmonburgerswithbas_86430')
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all("meta", attrs={'name':'description'})
# Out:
# [<meta content="These tasty salmon burgers are a healthy barbecue option. Skip the mayo if you want to be super-healthy." data-rh="true" name="description"/>]

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-touch blocks-touchscreen-disabled b-reith-sans-font b-reith-serif-font b-pw-1280" lang="en">
# <head>
# <link crossorigin="" href="//nav.files.bbci.co.uk" rel="preconnect"/>
# <link href="//mybbc.files.bbci.co.uk" rel="preconnect"/>
# <link href="//fig.bbc.co.uk" rel="preconnect"/>
# <link href="//mvt.api.bbc.com" rel="preconnect"/>
# <link href="//idcta.api.bbc.co.uk" rel="preconnect"/>
# <link href="//ichef.bbci.co.uk" rel="preconnect"/>
# <link href="//static.chartbeat.com" rel="preconnect"/>
# <link href="//ping.chartbeat.net" rel="preconnect"/>
# <link href="//sa.bbc.co.uk" rel="preconnect"/>
# <link as="style" data-chunk="main" href="https://food.files.bbci.co.uk/kandl-food/3057/css/styles.css" rel="preload"/>
# <link as="script" data-chunk="main" href="https://food.files.bbci.co.uk/kandl-food/3057/javascript/styles.37ede912.js" rel="preload"/>
# ...
